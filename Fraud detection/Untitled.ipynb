# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\dell\Downloads\creditcard.csv\creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(1081)

# %%
df = df.drop_duplicates()

# %%
df.groupby('Class').sum()
# Out:
#                Time           V1           V2           V3           V4  \
# Class
# 0      2.686231e+10  3806.535755 -2784.158970  3640.784209 -2957.154175
# 1      3.805309e+07 -2127.686501  1611.021295 -3183.100307  2115.535550
#
#                 V5          V6           V7          V8           V9  ...  \
# Class                                                                 ...
# 0      1917.280388  354.278523  2959.109499 -693.319832   740.081389  ...
# 1     -1398.754067 -677.580949 -2448.206428  450.889421 -1192.964723  ...
#
#               V20         V21        V22         V23         V24        V25  \
# Class
# 0     -138.478775 -325.825207 -45.243842  101.853734  111.218175 -85.145181
# 1      191.585259  220.678302  40.980132  -45.627547  -50.442130  19.210950
#
#              V26         V27         V28       Amount
# Class
# 0      18.534525  399.102925  118.264846  25043410.29
# 1      23.865797  101.114984   37.021827     58591.39
#
# [2 rows x 30 columns]

# %%
df['Class'].value_counts(normalize = True)*100
# Out:
# Class
# 0    99.83329
# 1     0.16671
# Name: proportion, dtype: float64

# %%
not_fraud = df[df['Class'] == 0]

# %%
not_fraud1= not_fraud.head(250)

# %%
type(not_fraud1)
# Out:
# pandas.core.frame.DataFrame

# %%
not_fraud2 = not_fraud.tail(250)

# %%
type(not_fraud2)
# Out:
# pandas.core.frame.DataFrame

# %%
not_fraud = pd.concat([not_fraud1,not_fraud2], axis = 0 )

# %%
not_fraud.shape
# Out:
# (500, 31)

# %%
not_fraud
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
fraud = df[df['Class'] == 1]

# %%
df = pd.concat([not_fraud, fraud], axis = 0)

# %%
df.shape
# Out:
# (973, 31)

# %%
df['Amount'] = np.log1p(df['Amount'])

# %%
new_df = df

# %%
new_df = new_df.drop(columns = ['Class', 'Time'])

# %%
y = df['Class']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
model = DecisionTreeClassifier(max_depth = 3)
x_train_df , x_test, y_train_df,y_test = train_test_split(new_df , y,test_size = 0.3, random_state = 42 )

# %%
model.fit(new_df, y )
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
prediction = model.predict(x_test)

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
score = accuracy_score(prediction, y_test)

# %%
print(score)
# Out:
# 0.9246575342465754

# %%
clr = classification_report(prediction, y_test)

# %%
print(clr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.89      0.93       169
#            1       0.86      0.98      0.92       123
#
#     accuracy                           0.92       292
#    macro avg       0.92      0.93      0.92       292
# weighted avg       0.93      0.92      0.93       292

# %%
cfm = confusion_matrix(prediction,y_test)

# %%
print(cfm)
# Out:
# [[150  19]
#  [  3 120]]

# %%
#The confusion matrix means that there are total 169 not fraud transanctions out of which 150 were predicted correctly
#and fraud transanctions were 123 out of which 120 were predicted correctly .
